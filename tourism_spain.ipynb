# %%
from tourism import tourism

# %%
# load data, which takes a few seconds
handler = tourism.load('data/galicia.osm.pbf')
# Out:
# Loading data/galicia.osm.pbf
# Number of tourism nodes: 93586
# Uncounted tourism locations: 980
# Tags: set()

# %% [markdown]
# ## Rough plotting to see if this looks like a map

# %%
import matplotlib.pyplot as plt

# %%
lats, lons, types, types = zip(*handler.geo_points)

# %%
len(lats)
# Out:
# 3707

# %%
# Snippet inspired by examples on
# https://towardsdatascience.com/easy-steps-to-plot-geographic-data-on-a-map-python-11217859a2db
fig, ax = plt.subplots(figsize = (8,7))
ax.scatter(lons, lats, zorder=1, alpha= 0.2, c='b', s=10)
ax.set_title('Tourist locations in Galicia, Spain')
# ax.imshow(ruh_m, zorder=0, extent = BBox, aspect= 'equal')
# Out:
# Text(0.5, 1.0, 'Tourist locations in Galicia, Spain')

# %% [markdown]
# ## Play with Dataframe

# %%
df = handler.get_dataframe()

# %%
df.head()
# Out:
#          lat       lon   type subtype
# 0  41.875760 -8.838838  place    town
# 1  42.113041 -8.259342  place    town
# 2  41.940391 -8.743607  place    town
# 3  42.078702 -8.481390  place    town
# 4  42.027045 -8.642883  place    town

# %%
# uncomment to write csv
# df.to_csv('tourism/data.csv')

# %%
import pandas as pd
df_in = pd.read_csv('tourism/data.csv', usecols=['lat', 'lon', 'type', 'subtype'])

# %%
df_in.head()
# Out:
#          lat       lon   type subtype
# 0  41.875760 -8.838838  place    town
# 1  42.113041 -8.259342  place    town
# 2  41.940391 -8.743607  place    town
# 3  42.078702 -8.481390  place    town
# 4  42.027045 -8.642883  place    town

# %%
df_in.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x118f89990>,
# ...
#       dtype=object)

# %%
df_in['type'].apply(pd.value_counts).plot(kind='bar', subplots=True)

# %%
df_in[df_in['type']=='place']['subtype'].value_counts()
# Out:
# locality             49291
# hamlet               25132
# isolated_dwelling     1446
# village               1431
# neighbourhood         1054
# yes                    450
# suburb                 351
# municipality           112
# town                   111
# civil_parish           103
# island                  67
# islet                   38
# city_block              29
# county                  21
# quarter                 14
# farm                     8
# city                     7
# square                   6
# province                 4
# ward                     1
# village;hamlet           1
# state                    1
# region                   1
# parish                   1
# abandoned                1
# plot                     1
# Name: subtype, dtype: int64

# %%
df_in.loc[df_in['type']=='tourism']['subtype'].apply(pd.value_counts).plot(kind='bar', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x183ed8d50>,
# ...
#       dtype=object)
# Error in callback <function flush_figures at 0x118f8c830> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/miniconda3/envs/fire-tourism/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~/miniconda3/envs/fire-tourism/lib/python3.7/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      41             display(
#      42                 figure_manager.canvas.figure,
# ---> 43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
# ...
